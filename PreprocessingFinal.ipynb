# %% [markdown]
# <a href="https://colab.research.google.com/github/mikeisk/GlobalAiHub-SummerCamp-22/blob/main/PreprocessingFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
zip_adres = "/content/drive/MyDrive/kagglecatsanddogs_5340.zip"
# !cp "{zip_adres}" .

# %%
# !unzip -q kagglecatsanddogs_5340.zip

# %%
# !rm kagglecatsanddogs_5340.zip

# %%
import os
import cv2
from tqdm import tqdm

CATEGORIES = ["Cat", "Dog"]
DIR = "PetImages"
SIZE = 128

data = []

for category in CATEGORIES:
  folder_address = os.path.join(DIR,category)
  value = CATEGORIES.index(category)
  for image_name in tqdm(os.listdir(folder_address)):
    image_address = os.path.join(folder_address,image_name)
    image = cv2.imread(image_address, cv2.IMREAD_COLOR)
    if(image is None):
      print("Error")
    else:
      image = cv2.resize(image,(SIZE,SIZE))
      data.append([image,value])
# Out:
#   7%|▋         | 937/12501 [00:01<00:19, 587.13it/s]
# Error
#   8%|▊         | 1058/12501 [00:01<00:19, 590.83it/s]
# Error
#  14%|█▍        | 1736/12501 [00:03<00:18, 581.50it/s]
# Error
#  21%|██        | 2600/12501 [00:04<00:16, 608.64it/s]
# Error
#  23%|██▎       | 2905/12501 [00:04<00:16, 591.11it/s]
# Error
# Error
#  26%|██▌       | 3207/12501 [00:05<00:15, 587.83it/s]
# Error
#  29%|██▊       | 3574/12501 [00:06<00:15, 585.31it/s]
# Error
#  43%|████▎     | 5333/12501 [00:09<00:11, 614.76it/s]
# Error
#  46%|████▌     | 5705/12501 [00:09<00:11, 608.78it/s]
# Error
#  52%|█████▏    | 6563/12501 [00:11<00:10, 591.46it/s]
# Error
#  54%|█████▎    | 6689/12501 [00:11<00:09, 608.68it/s]
# Error
# Error
# Error
#  59%|█████▉    | 7382/12501 [00:12<00:08, 620.64it/s]
# Error
#  60%|██████    | 7507/12501 [00:12<00:08, 613.59it/s]
# Error
#  64%|██████▎   | 7943/12501 [00:13<00:07, 610.19it/s]
# Error
#  74%|███████▎  | 9198/12501 [00:15<00:05, 601.04it/s]
# Error
#  75%|███████▍  | 9327/12501 [00:15<00:05, 619.49it/s]
# Error
#  78%|███████▊  | 9759/12501 [00:16<00:04, 599.50it/s]
# Error
#  88%|████████▊ | 10943/12501 [00:18<00:02, 620.42it/s]
# Error
# Error
#  90%|█████████ | 11259/12501 [00:18<00:01, 622.73it/s]
# Error
#  92%|█████████▏| 11443/12501 [00:19<00:01, 592.11it/s]
# Error
# Error
# 100%|██████████| 12501/12501 [00:20<00:00, 599.31it/s]
#   4%|▍         | 476/12501 [00:00<00:21, 568.98it/s]
# Error
#   8%|▊         | 1005/12501 [00:01<00:20, 569.49it/s]
# Error
#  11%|█▏        | 1429/12501 [00:02<00:19, 578.25it/s]
# Error
#  17%|█▋        | 2081/12501 [00:03<00:18, 578.60it/s]
# Error
# Error
#  21%|██        | 2612/12501 [00:04<00:16, 590.06it/s]
# Error
#  24%|██▍       | 2977/12501 [00:05<00:16, 587.57it/s]
# Error
# Error
# Error
#  30%|███       | 3755/12501 [00:06<00:15, 561.92it/s]
# Error
#  33%|███▎      | 4124/12501 [00:07<00:14, 581.80it/s]
# Error
#  35%|███▍      | 4367/12501 [00:07<00:13, 582.08it/s]
# Error
#  42%|████▏     | 5188/12501 [00:08<00:12, 580.80it/s]
# Error
#  43%|████▎     | 5367/12501 [00:09<00:12, 582.68it/s]
# Error
#  45%|████▍     | 5616/12501 [00:09<00:11, 604.96it/s]
# Error
#  47%|████▋     | 5857/12501 [00:10<00:11, 573.95it/s]
# Error
#  49%|████▉     | 6168/12501 [00:10<00:10, 590.01it/s]
# Error
#  53%|█████▎    | 6645/12501 [00:11<00:10, 557.62it/s]
# Error
#  55%|█████▌    | 6885/12501 [00:11<00:09, 581.11it/s]
# Error
# Error
# Error
#  64%|██████▎   | 7958/12501 [00:13<00:07, 581.83it/s]
# Error
#  67%|██████▋   | 8375/12501 [00:14<00:07, 588.01it/s]
# Error
#  70%|██████▉   | 8742/12501 [00:15<00:06, 588.67it/s]
# Error
#  72%|███████▏  | 9040/12501 [00:15<00:05, 590.88it/s]
# Error
# Error
#  82%|████████▏ | 10229/12501 [00:17<00:04, 557.36it/s]
# Error
#  95%|█████████▌| 11883/12501 [00:21<00:01, 565.27it/s]
# Error
#  96%|█████████▋| 12057/12501 [00:21<00:00, 569.20it/s]
# Error
# Error
#  98%|█████████▊| 12239/12501 [00:21<00:00, 591.54it/s]
# Error
# 100%|██████████| 12501/12501 [00:22<00:00, 560.10it/s]

# %%
from matplotlib import pyplot
pyplot.imshow(data[15000][0])

# %%
import random
random.shuffle(data)

X = []
Y = []

for x,y in data:
  X.append(x)
  Y.append(y)

del data

# %%
pyplot.imshow(cv2.cvtColor(X[45], cv2.COLOR_BGR2RGB))
print(Y[1])
# Out:
# 0

# %%
import numpy as np

X = np.array(X)
Y = np.array(X)

# %%
x_train = []
y_train = []
x_val = []
y_val = []
x_test = []
y_test = []

# %%
x_train = X[:20000]
y_train = Y[:20000]

x_val = X[:2500]
y_val = Y[:2500]

x_test = X[:2500]
y_test = Y[:2500]

# %%
x_train = np.array(x_train)
y_train = np.array(y_train)

x_val = np.array(x_val)
y_val = np.array(y_val)

x_test = np.array(x_test)
y_test = np.array(y_test)

# %%
import pickle

# %%
with open("/content/drive/MyDrive/pickles/x_train_pickle","wb") as f:
  pickle.dump(x_train,f)
with open("/content/drive/MyDrive/pickles/y_train_pickle","wb") as f:
  pickle.dump(y_train,f)

with open("/content/drive/MyDrive/pickles/x_val_pickle","wb") as f:
  pickle.dump(x_val,f)
with open("/content/drive/MyDrive/pickles/y_val_pickle","wb") as f:
  pickle.dump(y_val,f)

with open("/content/drive/MyDrive/pickles/x_test_pickle","wb") as f:
  pickle.dump(x_test,f)
with open("/content/drive/MyDrive/pickles/y_test_pickle","wb") as f:
  pickle.dump(y_test,f)
